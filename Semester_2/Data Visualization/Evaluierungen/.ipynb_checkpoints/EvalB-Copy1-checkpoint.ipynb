# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from copy import deepcopy
from datetime import datetime
from scipy import stats
from collections import Counter

from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency

plt.style.use("seaborn")

u, s = "µ", "σ"

# %%
def test_normal(x):
    k2, p = stats.normaltest(x)
    alpha = 1e-3
    print("p = {:g}".format(p))
    if p < alpha:  # null hypothesis: x comes from a normal distribution
        print("It's not a normal distribution")
    else:
        print("It's a normal distribution")
        
    plt.hist(x)
    plt.show()

# %%
def stackedbarchart_from_contingency(contingencyTable,xlabel=None,title=None):
    percentages = []


    for i,target_col in enumerate(contingencyTable.columns):
        percentage_onelabel = []
        for j,label in enumerate(contingencyTable.index):
            val = contingencyTable.loc[label][target_col]
            summe = contingencyTable.loc[label].sum()
            percentage = (val/summe) *100
            percentage_onelabel.append(percentage)

        val = contingencyTable[target_col].sum()
        total = contingencyTable.sum().sum()

        percentage_onelabel.append(val*100/total)
        percentages.append(percentage_onelabel)


    percentages_backup = deepcopy(percentages)
    # print('per',percentages)

    # add up preceeding percentages for barchart
    for i in range(1,len(percentages)):
        for j in range(0,len(percentages[i])):
            percentages[i][j] += percentages[i-1][j]

    # print(percentages,contingencyTable.index)
    colors = ['grey','lightgrey','black','dimgrey']
    plt.figure(figsize=(5,5))
    
    # print(percentages)
    
    labels = list(contingencyTable.index)+['total']
    labels = [str(v) for v in labels]

    for i in range(len(percentages)-1,-1,-1):
        
        plt.bar(labels,percentages[i],label=contingencyTable.columns[i],color=colors[i])
    
    plt.ylabel('Percentage')
    plt.xlabel(xlabel)
    plt.title(title)
    
    plt.legend(loc="upper right")
    plt.show()

    # print('In Percent ',list(contingencyTable.index)+['total'])

    data = []
    data_transposed = []
    for i in range(len(percentages_backup)-1,-1,-1):
        # print(contingencyTable.columns[i],percentages_backup[i])
        data_transposed.append(percentages_backup[i])

    data_transposed = list(reversed(data_transposed))
    for i in range(len(data_transposed[0])):
        row = []
        for j in range(len(data_transposed)):
            row.append(data_transposed[j][i])
        
        data.append(row)
    
    df = pd.DataFrame(data=data,columns=contingencyTable.columns, index=list(contingencyTable.index)+['total'])
    try:
        totalratio = df.loc['total'][0] /df.loc['total'][1]
        df['Abweichung von Total'] = df.iloc[:,0]/df.iloc[:,1] - totalratio
    except:
        print('Cant generate total')

    print(df)
    print("\n\n")

# %%
df = pd.read_csv("data/Absenteeism_at_work.csv", delimiter=";")
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df.tail()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %% [markdown]
# # Aufgabe 1

# %%
df_count_absence = df[["ID", "Age"]].groupby("ID").count().sort_values("Age", ascending=False).reset_index()
df_count_absence.head(3)
# Out:
#    ID  Age
# 0   3  113
# 1  28   76
# 2  34   55

# %%
x_data = range(len(df_count_absence["Age"]))
y_data = df_count_absence["Age"]
yerr = None

title = "Anzahl (Count) der Abwesenheiten"
x_label = "\nMitarbeiter als IDs"
y_label = "Anzahl der Abwesenheiten"

caption = f"""
################################################
Abbildung 1:
In dieser Abbildung ist die Anzahl an Abwesenheiten für die einzelnen Mitarbeiter abgebildet.
Es ist zu erkennen, dass Mitarbeiter mit ID=3 mit 113 Abwesenheiten "Negativsieger" ist.
################################################
"""

plt.figure(figsize=(15, 8))

plt.title(title, size=20)
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xticks(
    range(len(x_data)),
    df_count_absence["ID"],
    rotation=90
)

plt.bar(x=x_data, height=y_data, color="gray")
# plt.errorbar(x_data, y=y_data, yerr=yerr, ls="none", color="gray", capsize=5, capthick=3)
# for i, v in enumerate(y_data.to_list()):
#     plt.text(
#         list(range(len(x_data)))[i], 
#         v + 300, str(v), 
#         horizontalalignment="center", 
#         verticalalignment="bottom", 
#         color="black"
#     )

plt.show()
print(caption)
# Out:
# ################################################
# Abbildung 1:
# In dieser Abbildung ist die Anzahl an Abwesenheiten für die einzelnen Mitarbeiter abgebildet.
# Es ist zu erkennen, dass Mitarbeiter mit ID=3 mit 113 Abwesenheiten "Negativsieger" ist.
# ################################################

# %%
df_average_absence = df[["ID", "Absenteeism time in hours"]].groupby("ID").mean() # .sort_values("Absenteeism time in hours", ascending=False).reset_index()
df_average_absence["stds"] =  df[["ID", "Absenteeism time in hours"]].groupby("ID").std()
df_average_absence = df_average_absence.sort_values("Absenteeism time in hours", ascending=False).reset_index()
df_average_absence.head(3)
# Out:
#    ID  Absenteeism time in hours       stds
# 0   9                  32.750000  51.505201
# 1  26                  16.600000  26.698315
# 2  14                  16.413793  26.730824

# %%
x_data = range(len(df_average_absence["ID"]))
y_data = df_average_absence["Absenteeism time in hours"]
yerr = df_average_absence["stds"]

title = "Durschnittliche Dauer der Abwesenheiten"
x_label = "\nMitarbeiter als IDs"
y_label = "Durchschnittliche Abwesenheit in Studen"

caption = f"""
################################################
Abbildung 2:
Hier ist die durschnittliche Fehlzeit der Mitarbeiter abgebildet.
Es ist zu erkennen, dass andere Mitarbeiter als in Abb. 1 die höchsten 
durchschnittlichen Abwesenheiten haben. Jedoch kann dies aufgrund der hohen
Standardabweichungen auch unrepräsentativ sein.
################################################
"""

plt.figure(figsize=(15, 8))

plt.title(title, size=20)
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xticks(
    range(len(x_data)),
    df_average_absence["ID"],
    rotation=90
)

plt.bar(x=x_data, height=y_data, color="gray")
plt.errorbar(x_data, y=y_data, yerr=yerr, ls="none", color="gray", capsize=5, capthick=3)
plt.ylim(0)
# for i, v in enumerate(y_data.to_list()):
#     plt.text(
#         list(range(len(x_data)))[i], 
#         v + 300, str(v), 
#         horizontalalignment="center", 
#         verticalalignment="bottom", 
#         color="black"
#     )

plt.show()
print(caption)
# Out:
# ################################################
# Abbildung 2:
# Hier ist die durschnittliche Fehlzeit der Mitarbeiter abgebildet.
# Es ist zu erkennen, dass andere Mitarbeiter als in Abb. 1 die höchsten
# durchschnittlichen Abwesenheiten haben. Jedoch kann dies aufgrund der hohen
# Standardabweichungen auch unrepräsentativ sein.
# ################################################

# %%
# Die Person mit der ID=3 hat mit insgesamt 113 Abwesenheiten die meisten (Dies ist der Count und nicht die Summe, da ich die Aufgabe so verstanden habe. Falls Sie doch die Summe haben wollen, dann ist es auch ID=3 mit 482h).
# Die Person mit der ID=9 hat mit durchschnittlich 32.75h Abwesenheit den höchsten Schnitt.

# %% [markdown]
# # Aufgabe 2

# %%
df = pd.read_csv("data/Absenteeism_at_work.csv", delimiter=";")
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df_gviel = df[(df["ID"] == 9) | (df["ID"] == 26) | (df["ID"] == 14)]
# df_gviel = df_gviel.groupby("ID").mean().sort_values("Absenteeism time in hours", ascending=False).reset_index()

df_gwen = df[(df["ID"] == 35) | (df["ID"] == 4) | (df["ID"] == 8)]
# df_gwen = df_gwen.groupby("ID").mean().sort_values("Absenteeism time in hours", ascending=False).reset_index()

# %%
print(df_gviel.shape)
df_gviel.head()
# Out:
# (42, 21)
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 8    14                  19                 7                2        1
# 44   14                  23                 9                4        1
# 85   14                  10                11                2        4
# 89   14                   6                11                6        4
# 116  14                  18                 1                3        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 8                       155                               12            14
# 44                      155                               12            14
# 85                      155                               12            14
# 89                      155                               12            14
# 116                     155                               12            14
#
# ...

# %%
print(df_gwen.shape)
df_gwen.head()
# Out:
# (4, 21)
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 276   8                   0                 9                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 276                     231                               35            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 276   39                 294.217  ...                     1          1    2
# ...

# %%
print("Einträge Gviel: ", df_gviel.shape[0])
print("Einträge Gwenig: ", df_gwen.shape[0])
print("Einträge Gviel: 42 Einträge Gwenig: 4 (BEACHTE: bei Gwenig wurden IDs 4, 8, 35 verwendet. Diese haben zwar Einträge, welche jedoch ohne tatsächliche Abwesenheit hinzugefügt wurden. Sofern man diese Einträge rausrechnen würde, käme #gwenig = 0 Einträge raus.")
# Out:
# Einträge Gviel:  42
# Einträge Gwenig:  4
# Einträge Gviel: 42 Einträge Gwenig: 4 (BEACHTE: bei Gwenig wurden IDs 4, 8, 35 verwendet. Diese haben zwar Einträge, welche jedoch ohne tatsächliche Abwesenheit hinzugefügt wurden. Sofern man diese Einträge rausrechnen würde, käme #gwenig = 0 Einträge raus.

# %%
df[(df["ID"]== 14) & (df["Absenteeism time in hours"] == 0)]
# Out:
# Empty DataFrame
# Columns: [ID, Reason for absence, Month of absence, Day of the week, Seasons, Transportation expense, Distance from Residence to Work, Service time, Age, Work load Average/day , Hit target, Disciplinary failure, Education, Son, Social drinker, Social smoker, Pet, Weight, Height, Body mass index, Absenteeism time in hours]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[df["ID"] == 8]
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 276   8                   0                 9                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 276                     231                               35            14
# 738                     231                               35            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 276   39                 294.217  ...                     1          1    2
# 738   39                 271.219  ...                     0          1    2
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 276               1              0    2     100     170               35
# 738               1              0    2     100     170               35
#
#      Absenteeism time in hours
# 276                          0
# ...

# %%
df_average_absence.tail(5)
# Out:
#     ID  Absenteeism time in hours     stds
# 31  33                   3.041667  2.45798
# 32  19                   2.000000  2.00000
# 33   8                   0.000000  0.00000
# 34   4                   0.000000      NaN
# 35  35                   0.000000      NaN

# %% [markdown]
# # Aufgabe 3

# %%
df_gviel["v"] = [True] * len(df_gviel)
df_gwen["v"] = [False] * len(df_gwen)

df_g = pd.concat([df_gviel, df_gwen])
df_g.tail()
# Out:
# C:\Users\I550854\AppData\Local\Temp/ipykernel_17208/2780265348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gviel["v"] = [True] * len(df_gviel)
# C:\Users\I550854\AppData\Local\Temp/ipykernel_17208/2780265348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gwen["v"] = [False] * len(df_gwen)
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 729   9                   6                 7                3        1
# ...

# %%
p_vals = []

for feature in df_g.columns:
    if feature in ["ID", "v"]:
        continue
        
    crosstab = pd.crosstab(df_g[feature], df_g["v"])
    chi2, p_val, dof, expectedFreq=chi2_contingency(crosstab)
    
    if p_val < 0.05:
        p_vals.append((feature, p_val))
        
p_vals.sort(key=lambda x:x[1])
p_vals
# Out:
# [('Age', 9.082105818889259e-09),
#  ('Transportation expense', 9.082105818889289e-09),
#  ('Height', 9.533287632634929e-08),
#  ('Pet', 1.7086471474772583e-07),
#  ('Body mass index', 2.2213142113103693e-07),
#  ('Weight', 3.659809478112642e-07),
#  ('Distance from Residence to Work', 5.095943997441882e-07),
#  ('Reason for absence', 1.423634445830644e-05),
#  ('Absenteeism time in hours', 5.3169987041074395e-05),
#  ('Month of absence', 0.00017825821602301836),
#  ('Son', 0.0006674433295612812),
#  ('Hit target', 0.004427015346182762),
#  ('Work load Average/day ', 0.009121894333384806)]

# %%
ylabels = ["Alter in Jahren", "Kosten in Geldeinheit", "Größe in inch", "Anzahl Haustiere", "BMI", "Gewicht in kg", "Distanz zur Arbeit", "Abwesenheitsgrund", "Abwesenheit in Studen", "Monat der Abwesenheit", "Anzahl Kinder", "Hit target", "Arbeitszeit pro Tag"]

def plot_bars(x, y, yerr, title, xl, yl):
    plt.title(title)
    plt.xlabel(xl)
    plt.ylabel(yl)
    plt.xticks(
        range(2),
        ["Gruppe Viel", "Gruppe Wenig"]
    )

    plt.bar(x=x, height=y, color="gray")
    plt.errorbar(x, y=y, yerr=yerr, ls="none", color="gray", capsize=5, capthick=3)
    plt.ylim(0)


plt.figure(figsize=(20, 20))
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.99, 
                    wspace=0.4, 
                    hspace=0.4)

for idx, feature in enumerate(p_vals):
    plt.subplot(5, 3, idx + 1)
    plot_bars(
        range(2),
        [df_gviel[feature[0]].mean(), df_gwen[feature[0]].mean()],
        [df_gviel[feature[0]].std(), df_gwen[feature[0]].std()],
        f"'{feature[0]}' Gruppenvergleich\np-Wert={feature[1]}",
        f"Vorhandene Gruppen",
        ylabels[idx]
    )
plt.show()
plt.savefig("hallo.pdf")

# %% [markdown]
# # Aufgabe 4
